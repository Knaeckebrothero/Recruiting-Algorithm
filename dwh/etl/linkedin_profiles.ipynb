# %%
# Create mapping for values
mapping = {'old_value1': 'new_value1', 'old_value2': 'new_value2'}
df['column_name'] = df['column_name'].map(mapping)

# %%
# Rename simple attributes
df = df.rename(columns={
    'public_identifier': 'linkedInPubId',
    'profile_pic_url': 'profilePictureUrl',
    'background_cover_image_url': 'backgroundPictureUrl',
    'first_name': 'firstName',
    'last_name': 'lastName',
    'profile_headline': 'profileHeadline',
    'summary': 'profileText',
    'location': 'idLocation',
    'languages': 'idLanguages',
    'connections': 'connections',
    'github': 'github',
})

def map_simple_data(json_object):
    profilePictureUrl = 
    backgroundPictureUrl = 
    firstName = json_object.get('firstName')
    lastName = json_object.get('lastName')
    occupation = json_object.get('occupation')
    profileHeadline = json_object.get('profileHeadline')
    profileText = json_object.get('profileText')
    idLocation = json_object.get('idLocation')
    idLanguages = json_object.get('idLanguages')
    connections = json_object.get('connections')
    github = json_object.get('github')
    facebook = json_object.get('facebook')
    gender = json_object.get('gender')
    birthDate = json_object.get('birthDate')
    industry = json_object.get('industry')

    # Return dictionary of mapped values
    return {
        'linkedInPubId': json_object.get('public_identifier'),
        'profilePictureUrl': json_object.get('profile_pic_url'),
        'backgroundPictureUrl': json_object.get('background_cover_image_url'),
        'firstName': firstName,
        'lastName': lastName,
        'occupation': occupation,
        'profileHeadline': profileHeadline,
        'profileText': profileText,
        'idLocation': idLocation,
        'idLanguages': idLanguages,
        'connections': connections,
        'github': github,
        'facebook': facebook,
        'gender': gender,
        'birthDate': birthDate,
        'industry': industry
    }

# %%
# Imports
import os
import dotenv
from sqlalchemy import create_engine
import pandas as pd


# Load environment variables
dotenv.load_dotenv(dotenv.find_dotenv())
hostname = os.getenv('DATABASE_HOST')
user = os.getenv('DATABASE_USER')
password = os.getenv('DATABASE_PASSWORD')
database = os.getenv('DATABASE_NAME') 

# Set up database connection using SSL
db_engine = create_engine(f'mysql+pymysql://{user}:{password}@{hostname}/{database}', 
                       connect_args={
                           'ssl_ca': os.getenv('SSL_CA'),
                           'ssl_cert': os.getenv('SSL_CLIENT_CERT'),
                           'ssl_key': os.getenv('SSL_KEY')
                       })

"""
# !!!UNENCRYPTED CONNECTION!!!
For use within local network only!
db_engine = create_engine(f'mysql+pymysql://{user}:{password}@{hostname}/{database}') 
# !!!UNENCRYPTED CONNECTION!!!
"""

# %%
# Function to check data types and max lengths of values
def check_data(dataset):
    for column in dataset.columns:
        print(f'Column: {column}')
        print(f'Data type: {dataset[column].dtype}')
        try:
            print(f'Max length: {dataset[column].str.len().max()}')
        except:
            print('No string data ')
        print('---\n')

# %%
import os
import pandas as pd

path = os.getenv('DATASET_PATH')

# Read JSONs from file
df = pd.read_json(path, lines=True)

check_data(df)

# %%
# Function to check if language already exists
def check_and_insert_language(languages_data_entry, db_con):
    # Define query to find existing record
    query = """
        SELECT id
        FROM DIM_Languages
        WHERE listOfLanguages = %(listOfLanguages)s
    """
    
    # Query database for existing record
    query_result = pd.read_sql_query(query, db_con, params=languages_data_entry)

    # Check if a record was found or insert a new record
    if not query_result.empty:
        # Record found -> use its id
        entry_id = query_result.iloc[0]['id']
    else:
        # No record found -> insert new record and query its id
        languages_df = pd.DataFrame([languages_data_entry])
        languages_df.to_sql('DIM_Languages', con=db_con, if_exists='append', index=False)
        entry_id = pd.read_sql_query("SELECT LAST_INSERT_ID()", db_con).iloc[0, 0]
    
    # Return ID
    return entry_id

# Function to check if location already exists
def check_and_insert_location(location_data_entry, db_con):
    # Define query to find existing record
    query = """
        SELECT id
        FROM DIM_Location
        WHERE countryName = %(countryName)s
        AND stateName = %(stateName)s
        AND cityName = %(cityName)s
    """
    
    # Query database for existing record
    query_result = pd.read_sql_query(query, db_con, params=location_data_entry)

    # Check if a record was found or insert a new record
    if not query_result.empty:
        # Record found -> use its id
        entry_id = query_result.iloc[0]['id']
    else:
        # No record found -> insert new record and query its id
        location_df = pd.DataFrame([location_data_entry])
        location_df.to_sql('DIM_Location', con=db_con, if_exists='append', index=False)
        entry_id = pd.read_sql_query("SELECT LAST_INSERT_ID()", db_con).iloc[0, 0]
    
    # Return ID
    return entry_id

# %%
# Function to insert data origin and return its ID
def insert_data_origin(data_origin_name, data_origin_url, data_origin_comment):
    df_origin = pd.DataFrame([{
        'name': data_origin_name, 
        'url': data_origin_url, 
        'importDate': pd.Timestamp.now(), 
        'comment': data_origin_comment}])

    # Insert data into database
    df_origin.to_sql('DIM_DataOrigin', con=db_engine, if_exists='append', index=False)
    
    # Get ID of inserted data origin
    id_origin = pd.read_sql_query("SELECT LAST_INSERT_ID()", db_engine).iloc[0, 0]
    
    # Return ID of inserted data origin
    return id_origin

# %%
# Function to process person facts + dimensions and insert them into the database
def process_json(json_object, dimension_key_origin, db_con):
    """
    Extract data from LinkedIn profiles JSON and prepare it for insertion into DWH.

    Missing attributes will be added as comments, 
    complex attributes will be receiving their own tables and be set to id None for now.
    """
    
    # Extract data for Person table
    person_data = {
        'idOrigin': dimension_key_origin,
        'linkedInPubId': json_object.get('public_identifier'),
        'profilePictureUrl': json_object.get('profile_pic_url'),
        'backgroundPictureUrl': json_object.get('background_cover_image_url'),
        # Last name
        # First name
        'name': json_object.get('full_name'),
        'occupation': json_object.get('occupation'),
        'profileHeadline': json_object.get('headline'),
        'profileText': json_object.get('summary'),
        'idLocation': None,
        # Experiences
        # Education
        'idLanguages': None,
        # Accomplishments (organisations, publications, honor awards, patents, courses, projects, test scores)
        # Volunteer work
        # Certifications
        # Connections (included but no need to rename)
        # Activities
        # Similar named profiles
        # Articles
        # Groups
        # Skills
        # Infrared salary
        # Github (included but no need to rename)
        # Facebook (included but no need to rename)
        # Gender (will be converted to enum M/F)
        'birthDate': json_object.get('birth_date'),
        # Industry
        # Interests
    }

    # Extract data for Location table
    location_data = {
        'countryName': json_object.get('country_full_name'),
        'countryLetters': json_object.get('country'),
        'stateName': json_object.get('state'),
        'cityName': json_object.get('city')
    }
    
    # Extract data for Languages table
    languages_data = {
        'sumOfSpoken': len(json_object.get('languages', [])),
        'listOfLanguages': ', '.join(json_object.get('languages', []))
    }
    
    # Create DataFrames
    person_df = pd.DataFrame([person_data])
    languages_df = pd.DataFrame([languages_data])
    location_df = pd.DataFrame([location_data])
    
    # Insert languages and add ID to person
    languages_df.to_sql('DIM_Languages', con=db_con, if_exists='append', index=False)
    dimension_key_languages = pd.read_sql_query("SELECT LAST_INSERT_ID()", db_con).iloc[0, 0]
    person_df['idLanguages'] = dimension_key_languages
    
    # Insert location and add ID to person
    location_df.to_sql('DIM_Location', con=db_con, if_exists='append', index=False)
    dimension_key_location = pd.read_sql_query("SELECT LAST_INSERT_ID()", db_con).iloc[0, 0]
    person_df['idLocation'] = dimension_key_location
    
    # Insert person data and get ID
    person_df.to_sql('FACT_Person', con=db_con, if_exists='append', index=False)
    pk_person = pd.read_sql_query("SELECT LAST_INSERT_ID()", db_con).iloc[0, 0]
    
    # Return primary key of inserted person
    return pk_person

# %%
    
    # Extract data for Qualification table
    qualification_data = []
    for qualification in json_object.get('qualifications', []):
        qualification_data.append({
            'idOrigin': json_object.get('idOrigin'),
            'idPerson': None,  # Placeholder for idPerson
            'idDuration': None,  # Placeholder for idDuration
            'type': qualification.get('type'),
            'name': qualification.get('name'),
            'idInstitution': None,  # Placeholder for idInstitution
            'description': qualification.get('description')
        })



    qualification_df = pd.DataFrame(qualification_data)

    # Insert data into the database
    engine = create_engine('your_database_url')







    # Insert data into FACT_Qualification table
    qualification_df.to_sql('FACT_Qualification', con=engine, if_exists='append', index=False)

# %%
from pymongo import MongoClient


# Function to get schema of a MongoDB collection and return it as a dictionary
def get_schema(collection):
    schema = {}
    total_documents = collection.count_documents({})

    for document in collection.find():
        for key, value in document.items():
            if key not in schema:
                schema[key] = {
                    "types": set(),
                    "max_length": 0,
                    "max_value": None,
                    "null_count": 0
                }

            schema[key]["types"].add(type(value).__name__)

            if isinstance(value, str):
                length = len(value)
                if length > schema[key]["max_length"]:
                    schema[key]["max_length"] = length
                    schema[key]["max_value"] = value
            elif isinstance(value, (int, float)):
                if schema[key]["max_value"] is None or value > schema[key]["max_value"]:
                    schema[key]["max_value"] = value
            elif value is None:
                schema[key]["null_count"] += 1

    for key in schema:
        schema[key]["null_percentage"] = schema[key]["null_count"] / total_documents * 100

    return schema

# Function to print schema dictionary
def print_schema(schema_dict):
    for key, value in schema_dict.items():
        print(f"Field: {key}")
        print(f"  Types: {', '.join(value['types'])}")
        print(f"  Max Length: {value['max_length']}")
        print(f"  Max Value: {value['max_value']}")
        print(f"  Null Percentage: {value['null_percentage']:.2f}%")
        print()

# %%
import os
from dotenv import load_dotenv


# Load environment variables
load_dotenv()

# MongoDB connection details
client = MongoClient(os.getenv("MongoClientURI"))
db = client["dwh_sources"]

# Build the schema
schema = get_schema(db["kaggle_linkedin_proxycurl_profiles"])

# Print the schema
print_schema(schema)
# Out:
# Field: _id
#   Types: ObjectId
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: public_identifier
#   Types: str
#   Max Length: 379
#   Max Value: %E2%96%88%E2%95%91%E2%96%8C%E2%94%82%E2%95%91%E2%96%8C%E2%95%91%E2%96%8C%E2%94%82%E2%96%88%E2%94%82%E2%96%8C%E2%95%91%E2%94%82%E2%96%88%E2%95%91-%E2%96%88%E2%95%91%E2%96%8C%E2%94%82%E2%95%91%E2%96%8C%E2%95%91%E2%96%8C%E2%94%82%E2%96%88%E2%94%82%E2%96%8C%E2%95%91%E2%94%82%E2%96%88%E2%95%91%E2%96%88%E2%95%91%E2%94%82%E2%96%8C%E2%95%91%E2%94%82%E2%96%88%E2%95%91%E2%96%8C-86240924
#   Null Percentage: 0.00%
#
# Field: profile_pic_url
#   Types: NoneType, str
#   Max Length: 963
#   Max Value: https://s3.us-west-000.backblazeb2.com/proxycurl/person/%25E2%2596%2588%25E2%2595%2591%25E2%2596%258C%25E2%2594%2582%25E2%2595%2591%25E2%2596%258C%25E2%2595%2591%25E2%2596%258C%25E2%2594%2582%25E2%2596%2588%25E2%2594%2582%25E2%2596%258C%25E2%2595%2591%25E2%2594%2582%25E2%2596%2588%25E2%2595%2591-%25E2%2596%2588%25E2%2595%2591%25E2%2596%258C%25E2%2594%2582%25E2%2595%2591%25E2%2596%258C%25E2%2595%2591%25E2%2596%258C%25E2%2594%2582%25E2%2596%2588%25E2%2594%2582%25E2%2596%258C%25E2%2595%2591%25E2%2594%2582%25E2%2596%2588%25E2%2595%2591%25E2%2596%2588%25E2%2595%2591%25E2%2594%2582%25E2%2596%258C%25E2%2595%2591%25E2%2594%2582%25E2%2596%2588%25E2%2595%2591%25E2%2596%258C-86240924/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20220512%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20220512T060323Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=7d7ff4fe34b62cc000d7d2b5cc73cf8742db871cf19567de8c5f58fa69374a8a
#   Null Percentage: 9.68%
#
# Field: background_cover_image_url
#   Types: NoneType, str
#   Max Length: 961
#   Max Value: https://s3.us-west-000.backblazeb2.com/proxycurl/person/%25E2%2596%2588%25E2%2595%2591%25E2%2596%258C%25E2%2594%2582%25E2%2595%2591%25E2%2596%258C%25E2%2595%2591%25E2%2596%258C%25E2%2594%2582%25E2%2596%2588%25E2%2594%2582%25E2%2596%258C%25E2%2595%2591%25E2%2594%2582%25E2%2596%2588%25E2%2595%2591-%25E2%2596%2588%25E2%2595%2591%25E2%2596%258C%25E2%2594%2582%25E2%2595%2591%25E2%2596%258C%25E2%2595%2591%25E2%2596%258C%25E2%2594%2582%25E2%2596%2588%25E2%2594%2582%25E2%2596%258C%25E2%2595%2591%25E2%2594%2582%25E2%2596%2588%25E2%2595%2591%25E2%2596%2588%25E2%2595%2591%25E2%2594%2582%25E2%2596%258C%25E2%2595%2591%25E2%2594%2582%25E2%2596%2588%25E2%2595%2591%25E2%2596%258C-86240924/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20220512%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20220512T060323Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=9a394427ae66a1fd2c83b8c1ca53f704085cc844c336ee95dd47b6914854e0e9
#   Null Percentage: 16.44%
#
# Field: first_name
#   Types: str
#   Max Length: 144
#   Max Value: &#127289;&#127284;&#127304;&#127280;&#127298;&#127284;&#127284;&#127291;&#127280;&#127293;&#127280;&#127293;&#127299;&#127294;&#127293;&#127304;
#   Null Percentage: 0.00%
#
# Field: last_name
#   Types: NoneType, str
#   Max Length: 161
#   Max Value: &#3648;&#3614;&#3619;&#3634;&#3632;&#3594;&#3637;&#3623;&#3636;&#3605;&#3586;&#3634;&#3604;&#3627;&#3623;&#3634;&#3609;&#3652;&#3617;&#3656;&#3652;&#3604;&#3657;
#   Null Percentage: 3.23%
#
# Field: full_name
#   Types: str
#   Max Length: 229
#   Max Value: &copy;&trade;&reg;&#35377;&#32113;&#20625;&reg;&trade;&copy;&trade;&reg;&#35768;&#32479;&#26480;&reg;&trade;&copy; &copy;&trade;&reg;&#35377;&#32113;&#20625;&reg;&trade;&copy;&trade;&reg;&#35768;&#32479;&#26480;&reg;&trade;&copy;
#   Null Percentage: 0.00%
#
# Field: occupation
#   Types: NoneType, str
#   Max Length: 198
#   Max Value: NEW INTELLECTUAL PRODUCTIVITY SETUPS | 20+% HIGHER OUTPUT | EXECUTE DEEP WORK | NO PSEUDO WORK  at Barington Consulting | Pillar #1: Power Positioning Gameplan | OKRs | Clear Priorities | Strategy |
#   Null Percentage: 26.57%
#
# Field: headline
#   Types: NoneType, str
#   Max Length: 220
#   Max Value: Consulting, Strategy & Execution. Director of the danish online marketing agency OnlineSynlighed.dk | Partner & director of the copyright service illegalcopying.com | Online Visibility • SEO • SEM • Reputation Management
#   Null Percentage: 5.18%
#
# Field: summary
#   Types: NoneType, str
#   Max Length: 2762
#   Max Value: 知恵と信仰 (武士道)(Bushido-Spirit)&lt; 1 3, 1 5 1 + つ な が り [ Contacts  ( Connections )] &gt; 4 3, 1 2 1 +&lt; In Memorial &gt;フォロー中 1 6, 3 2 1 +&lt;  Memorial &gt;     フォロー 1 5, 3 1 1 +&lt; Professional つ な が り [ Contacts (Connections) ]  (1):遵從日本武士道精神  (2):接受西方騎士精神(Knightship) 信 念: 剛 ; 勇 ; 烈 ; 戰 ; 義(My-Belief): %(堅持初衷是一種勇氣;放棄卻能知難而退仍是一種勇氣;停滯不前的怯懦則是自我消極的恥辱)% {Martial artist}: Magic Century Corporation --- しゃ ちょう さん &lt;Phantom Phase Technology&gt; President of International Company Limited Corporation (Daniel Liu) Judicial Scholar (Law Learning Monk) Second -- (Bachelor of Business) Aletheia University . Republic of China Peace talks in Taiwan openly deal with. Master of Laws, Cambridge University, UK Personal Ultimate Goal &lt;個人的な最終目標&gt; &lt;A&gt;Successful Big Business People (a)成功した大企業の人々 &lt;B&gt;Successful Barrister(b)成功した弁護士 &lt;C&gt;Successful Judge &lt;D&gt;The First Leader(d)最初のリーダー &lt;E&gt;Basketball Player(e)バスケットボール選手 &lt;F&gt;Martial Artist(f)武道家 &amp;1.Industry and Relatives.&amp;2.産業および親族 --&gt;Thailand.泰國&amp;America. The USA 感情狀態:戀愛中對象:秘密 名言:以自信為劍;以謙卑為盾 ---(救我中華;自戕不息;東方人絕對不是東亞病夫矣) (Asian Region International Friendship, Peace and Exchange Alliance .) (European and American Association for Regional Economic Cooperation Discusses the Park.) Liu Mr. (Tomoya Ryu) My WiKi : https://zh.wikipedia.org/wiki/User:%E5%8A%89_%E7%B4%AB%E4%BB%B2(%E3%81%84%E3%81%A1)  Google (私について) : https://www.google.com.tw/search?q=%E5%8A%89%E7%B4%AB%E4%BB%B2&amp;spf=1498575020650&amp;cad=h  Yahoo (私について) :https://tw.search.yahoo.com/search;_ylt=A8tUwJoycVJZ5ygAZYVt1gt.?p=劉紫仲&amp;fr=yfp-search-sb&amp;fr2=p%3As%2Cv%3Ai%2Cm%3Apivot&amp;stype=web(所有來自雅虎Yahoo  Twitter (私について) :https://twitter.com/a26184669  Yahoo Japan(About Me):https://search.yahoo.co.jp/search;_ylt=A2RA2C32eQNabCAAzuiJBtF7?p=%E5%8A%89%E7%B4%AB%E4%BB%B2&amp;search.x=1&amp;fr=top_ga1_sa&amp;tid=top_ga1_sa&amp;ei=UTF-8&amp;aq=-1&amp;oq=&amp;at=&amp;aa=&amp;ai=&amp;ts=1593  誕辰日:一九九O / 壹/貳拾伍 1990/01/25 (肆)星期四 男性  水瓶座 血型 :O型 A:International Traffic Maglev Train Planning Case B:China and Taiwan Seabed Train Planning Case C:Pacific Ocean Theme Park Planning Case D:Phantom Phase Technology Plan E:Switch Channel Space Displacement Technology Plan F:Anti-Relativism (Break Einstein's Theory of Relativity)   ( Speed X 1/E = 無限大) 父母親溺愛子女對父母親來說是天經地義的事, 但倘若子女到了30歲(而立之年)父母依舊要管教他簡直是&lt;滑天下之大稽&gt;!父母親根本讓子女無法獨立 ,甚至害死子女 子女冒犯父母就是"不孝"(對父母親而言只能用這句話來形容:&lt;冒天下之大不韙&gt;)我已經而立之年而我的父親依舊要我聽他的管束,我大可以用我練的武功擋掉他的不是!!簡直荒唐至極,難怪,要有人給我貼上亞斯伯格症的標籤,這才是最令我感到可笑的地方,滑天下之大稽! 我喜歡的銘言:老子的道德經第一章:&lt;道,可道 非常道 名, 可名 非常名&gt; Childless legal establishment , 30 years old , Nazen the father and mother misunderstanding example . For me is still the biggest joke in the wrold !! I never get sick. 鼠年春联賀新年: 去亗曾穷千里目 今年更上一层樓
#   Null Percentage: 61.18%
#
# Field: country
#   Types: str
#   Max Length: 2
#   Max Value: DK
#   Null Percentage: 0.00%
#
# Field: country_full_name
#   Types: NoneType, str
#   Max Length: 43
#   Max Value: United States Virgin Islands, United States
#   Null Percentage: 10.31%
#
# Field: city
#   Types: NoneType, str
#   Max Length: 74
#   Max Value: &#26085;&#26412; &#31070;&#22856;&#24029;&#30476; &#24029;&#23822;&#21306;
#   Null Percentage: 19.78%
#
# Field: state
#   Types: NoneType, str
#   Max Length: 47
#   Max Value: Central Singapore Community Development Council
#   Null Percentage: 48.81%
#
# Field: experiences
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: education
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: languages
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: accomplishment_organisations
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: accomplishment_publications
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: accomplishment_honors_awards
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: accomplishment_patents
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: accomplishment_courses
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: accomplishment_projects
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: accomplishment_test_scores
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: volunteer_work
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: certifications
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: connections
#   Types: NoneType, int
#   Max Length: 0
#   Max Value: 1531
#   Null Percentage: 27.99%
#
# Field: people_also_viewed
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: recommendations
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: activities
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: similarly_named_profiles
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: articles
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: groups
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: extra
#   Types: dict
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: skills
#   Types: NoneType, list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 12.35%
#
# Field: inferred_salary
#   Types: NoneType, dict
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 12.35%
#
# Field: gender
#   Types: NoneType, str
#   Max Length: 6
#   Max Value: female
#   Null Percentage: 33.37%
#
# Field: birth_date
#   Types: NoneType, dict
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 38.23%
#
# Field: industry
#   Types: NoneType, str
#   Max Length: 36
#   Max Value: mechanical or industrial engineering
#   Null Percentage: 34.22%
#
# Field: interests
#   Types: NoneType, list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 12.35%
#
# Field: personal_numbers
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: personal_emails
#   Types: list
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 0.00%
#
# Field: github
#   Types: NoneType
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 12.35%
#
# Field: facebook
#   Types: NoneType
#   Max Length: 0
#   Max Value: None
#   Null Percentage: 12.35%
